# %% [markdown]
# In the fundamentals course, you were introduced to plotting with matplotlib and the default plotting options included in Pandas. You learned how to create basic lineplots, scatterplots, histograms, qq plots, and boxplots. Before diving into more advanced plotting techniques, here is a brief refresher on the basics:
#
# * Plots should be as clean and simple as possible, including exactly as much information as is needed to make your point but no more.
# * Plots should be informatively labelled, with titles and axes in plain language the reader can easily understand. Remember, someone shouldn't have to read your code to understand what's being presented.
# * Basic plots show every datapoint.  Statistical plotting aggregates information to highlight features of data.
# * Let your choice of plot be guided by the data:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

foods = pd.DataFrame(np.random.randn(140,2),columns=['col1','col2'],index=["g1","g2"]*70).reset_index()
print(foods.iloc[0:6,:].head(n=20))

print('Line plots show data over time')
plt.plot(foods.iloc[0:6]['col1'])
plt.show()

print('Scatterplots show the relationship between two variables.')
plt.scatter(foods['col2'],foods['col1'])
plt.show()

print('Histograms show the distribution of the dataset and any outliers.')
plt.hist(foods['col1'])
plt.show()

print('QQ plots show how close a variable is to known distribution, and any outliers.')
norm= np.random.normal(0, 1, 140)
norm.sort()
plt.plot(norm, foods['col1'].sort_values(), "o") 
plt.show() 

print('Boxplots are used to compare groups and to identify differences in variance, as well as outliers.')
plt.boxplot([foods[foods['index']=='g1']['col1'],foods[foods['index']=='g2']['col1']])
plt.show()
# Out:
#   index      col1      col2
# 0    g1 -0.367395 -0.644814
# 1    g2 -0.429426  0.064632
# 2    g1  0.137024  0.918285
# 3    g2  1.064933  1.240131
# 4    g1  2.720445  1.226706
# 5    g2 -0.969338 -2.315275
# Line plots show data over time
# Scatterplots show the relationship between two variables.
# Histograms show the distribution of the dataset and any outliers.
# QQ plots show how close a variable is to known distribution, and any outliers.
# Boxplots are used to compare groups and to identify differences in variance, as well as outliers.
